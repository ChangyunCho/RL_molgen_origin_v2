# %% [markdown]
# * rdkit +a 참고
#
# https://gist.github.com/philopon/a75a33919d9ae41dbed5bc6a39f5ede2
#
# https://github.com/conda-incubator/condacolab

# %%
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ✨🍰✨ Everything looks OK!

# %%
# !conda install -c conda-forge rdkit
# Out:
# done
# done
#
# # All requested packages already installed.

# %%
# !conda install mpi4py
# Out:
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - mpi4py
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     cudatoolkit-11.1.1         |       h6406543_8        1.20 GB  conda-forge
#     libgcc-ng-11.2.0           |      h1d223b6_11         887 KB  conda-forge
#     libgomp-11.2.0             |      h1d223b6_11         427 KB  conda-forge
#     mpi-1.0                    |          openmpi           4 KB  conda-forge
#     mpi4py-3.1.2               |   py37h3e1c8c0_0         633 KB  conda-forge
#     openmpi-4.1.1              |       hbfc84c5_0         4.3 MB  conda-forge
#     openssl-1.1.1l             |       h7f98852_0         2.1 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        1.21 GB
#
# ...

# %%
pip install networkx==1.11

# %%
### github 에 공유된 폴더를 구글 드라이브 이용해 불러오기
### colab 에서 그냥 "rl_graph_generation-master.zip" 압축 푼 폴더 업로드 해도 괜찮음

#from google.colab import drive
#drive.mount('/content/drive')
#!unzip -qq "/content/drive/My Drive/RL/rl_graph_generation-master.zip"
#cd /content/drive/My Drive/RL/rl_graph_generation-master_2/rl-baselines/

# %%
pip install -e .
# Out:
# Obtaining file:///content/drive/MyDrive/RL/rl_graph_generation-master_2/rl-baselines
# ...
#      |████████████████████████████████| 1.5 MB 5.5 MB/s
# ...
#      |████████████████████████████████| 38.1 MB 1.2 MB/s
# ...
#      |████████████████████████████████| 306 kB 48.1 MB/s
# ...
#      |████████████████████████████████| 86 kB 4.6 MB/s
# ...
#      |████████████████████████████████| 489.6 MB 21 kB/s
# ...
#      |████████████████████████████████| 97 kB 5.6 MB/s
# ...
#      |████████████████████████████████| 1.3 MB 67.1 MB/s
# ...
#      |████████████████████████████████| 463 kB 43.6 MB/s
# ...
#      |████████████████████████████████| 2.1 MB 23.3 MB/s
# ...
#      |████████████████████████████████| 65 kB 3.5 MB/s
# ...
#      |████████████████████████████████| 1.1 MB 63.8 MB/s
# ...
#      |████████████████████████████████| 4.0 MB 42.8 MB/s
# ...
#      |████████████████████████████████| 5.8 MB 18.1 MB/s
# ...
#      |████████████████████████████████| 13.4 MB 34.1 MB/s
# ...
#      |████████████████████████████████| 42 kB 1.0 MB/s
# ...

# %%
cd /content/drive/My Drive/RL/rl_graph_generation-master_2/gym-molecule_
# Out:
# /content/drive/My Drive/RL/rl_graph_generation-master_2/gym-molecule_

# %%
pip install -e .
# Out:
# Obtaining file:///content/drive/My%20Drive/RL/rl_graph_generation-master_2/gym-molecule_
# ...
#   Using cached gym-0.21.0-py3-none-any.whl
# ...
#   Running setup.py develop for gym-molecule
# ...

# %%
pip install mujoco-py
# Out:
# ...
#      |████████████████████████████████| 2.4 MB 5.3 MB/s
# ...

# %%
cd /content/drive/My Drive/RL/rl_graph_generation-master_2/
# Out:
# /content/drive/My Drive/RL/rl_graph_generation-master_2

# %%
# !pip uninstall tensorflow
# Out:
# WARNING: Skipping tensorflow as it is not installed.

# %%
# !pip install tensorflow==1.15
# Out:
# ...
#      |████████████████████████████████| 412.3 MB 23 kB/s
# ...
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# ...
#   Using cached Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
# ...
#      |████████████████████████████████| 3.8 MB 60.1 MB/s
# ...
#      |████████████████████████████████| 50 kB 5.0 MB/s
# ...
#      |████████████████████████████████| 503 kB 51.1 MB/s
# ...
#   Using cached h5py-3.6.0-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (4.1 MB)
# ...
#   Created wheel for gast: filename=gast-0.2.2-py3-none-any.whl size=7538 sha256=b9f6d0c556b8ccb363f0bc77a804922865dbe682c1b9582be3f9fcbc6b25b9da
#   Stored in directory: /root/.cache/pip/wheels/21/7f/02/420f32a803f7d0967b48dd823da3f558c5166991bfd204eef3
# Successfully built gast
# ...
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.7.0
#     Uninstalling tensorflow-estimator-2.7.0:
#       Successfully uninstalled tensorflow-estimator-2.7.0
#   Attempting uninstall: tensorboard
# ...

# %%
# !pip install scipy
# !pip install tensorboardX
# Out:
# ...
#   Using cached scipy-1.7.3-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (38.1 MB)
# ...
#      |████████████████████████████████| 124 kB 5.4 MB/s
# ...

# %%
# !pip install ipykernel
# Out:
# ...
#      |████████████████████████████████| 125 kB 5.5 MB/s
# ...
#      |████████████████████████████████| 102 kB 9.6 MB/s
# ...
#      |████████████████████████████████| 790 kB 47.7 MB/s
# ...
#      |████████████████████████████████| 129 kB 69.8 MB/s
# ...
#      |████████████████████████████████| 1.9 MB 24.7 MB/s
# ...
#      |████████████████████████████████| 59 kB 4.6 MB/s
# ...
#      |████████████████████████████████| 1.6 MB 22.5 MB/s
# ...
#      |████████████████████████████████| 1.0 MB 62.4 MB/s
# ...
#      |████████████████████████████████| 374 kB 63.4 MB/s
# ...
#      |████████████████████████████████| 94 kB 2.0 MB/s
# ...
#      |████████████████████████████████| 86 kB 4.6 MB/s
# ...

# %%
# %reload_ext tensorboard

# %%
import tensorflow as tf
import datetime
# !rm -rf ./runs

# %%
pwd
# Out:
# '/content/drive/My Drive/RL/rl_graph_generation-master_2'

# %%
# %tensorboard --logdir ./runs/*
# Out:
# UsageError: Line magic function `%tensorboard` not found.

# %%
# !python ./run_molecule.py #2>/dev/null
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# [03:52:27] Explicit valence for atom # 10 N, 4, is greater than permitted
# [03:52:27] Explicit valence for atom # 10 N, 4, is greater than permitted
# [03:52:27] Explicit valence for atom # 4 C, 5, is greater than permitted
# [03:52:27] Explicit valence for atom # 11 C, 5, is greater than permitted
# [03:52:27] Explicit valence for atom # 2 C, 5, is greater than permitted
# [03:52:27] Explicit valence for atom # 10 N, 4, is greater than permitted
# [03:52:27] Explicit valence for atom # 0 C, 6, is greater than permitted
# [03:52:27] Explicit valence for atom # 23 N, 4, is greater than permitted
# [03:52:27] UFFTYPER: Unrecognized atom type: S_5+4 (15)
# [03:52:28] Explicit valence for atom # 3 O, 3, is greater than permitted
# [03:52:28] Explicit valence for atom # 3 O, 3, is greater than permitted
# [03:52:28] Explicit valence for atom # 0 C, 5, is greater than permitted
# ...

# %%
# Out:
# UsageError: Line magic function `%tensorboard` not found.
